// %% [markdown]
// # Iterators

// %% [markdown]
// 1. Use iterator methods to sum the values in a vector.

// %%
fn main() {
    let values = vec![1, 2, 3, 4];
    let total: i32 = __;

    assert_eq!(total, 10);
    println!("Success!");
}

main();

// %% [markdown]
// 2. Transform each item using `map()` and collect the results into a new vector.

// %%
fn main() {
    let values = vec![1, 2, 3];
    let doubled: Vec<i32> = __;

    assert_eq!(doubled, vec![2, 4, 6]);
    println!("Success!");
}

main();

// %% [markdown]
// 3. Filter the iterator to keep only even numbers.

// %%
fn main() {
    let values = vec![1, 2, 3, 4, 5];
    let evens: Vec<i32> = __;

    assert_eq!(evens, vec![2, 4]);
    println!("Success!");
}

main();

// %% [markdown]
// 4. Use `enumerate()` to find the index of the first value greater than 5.

// %%
fn main() {
    let values = vec![2, 4, 6, 8];
    let idx = __;

    assert_eq!(idx, Some(2));
    println!("Success!");
}

main();
